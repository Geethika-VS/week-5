# %%
import pandas as pd

# %%
df_iris=pd.read_excel('/content/iris.xls')

# %%
df_iris
# Out:
#       SL   SW   PL   PW  Classification
# 0    5.1  3.5  1.4  0.2     Iris-setosa
# 1    4.9  3.0  1.4  0.2     Iris-setosa
# 2    4.7  3.2  1.3  0.2     Iris-setosa
# 3    4.6  3.1  1.5  0.2     Iris-setosa
# 4    5.0  3.6  1.4  0.2     Iris-setosa
# ..   ...  ...  ...  ...             ...
# 145  6.7  3.0  5.2  2.3  Iris-virginica
# 146  6.3  2.5  5.0  1.9  Iris-virginica
# 147  6.5  3.0  5.2  2.0  Iris-virginica
# 148  6.2  3.4  5.4  2.3  Iris-virginica
# 149  5.9  3.0  5.1  1.8  Iris-virginica
#
# [150 rows x 5 columns]

# %% [markdown]
# 1. 1.	Load the Iris dataset using Pandas and display the first 5 rows.

# %%
df_iris.head()
# Out:
#     SL   SW   PL   PW Classification
# 0  5.1  3.5  1.4  0.2    Iris-setosa
# 1  4.9  3.0  1.4  0.2    Iris-setosa
# 2  4.7  3.2  1.3  0.2    Iris-setosa
# 3  4.6  3.1  1.5  0.2    Iris-setosa
# 4  5.0  3.6  1.4  0.2    Iris-setosa

# %% [markdown]
# 2. 2.	Calculate and display the mean, median, and standard deviation of sepal length (cm) for the entire dataset.

# %%
df_iris['SL'].mean()
# Out:
# 5.843333333333334

# %%
df_iris['SL'].median()
# Out:
# 5.8

# %%
df_iris['SL'].std()
# Out:
# 0.828066127977863

# %% [markdown]
# 3.	Find the maximum value of petal width (cm) and the corresponding species (target class).

# %%
df_iris[['PW','Classification']].max()
# Out:
# PW                           2.5
# Classification    Iris-virginica
# dtype: object

# %% [markdown]
# 4.	Filter the dataset to show only the rows where petal length (cm) is between 4.5 and 5.0

# %%
df_iris['SL'].max()
# Out:
# 7.9

# %% [markdown]
# 5.	Use iloc to display the values of the first row in the dataset.

# %%
df_iris.iloc[0]
# Out:
# SL                        5.1
# SW                        3.5
# PL                        1.4
# PW                        0.2
# Classification    Iris-setosa
# Name: 0, dtype: object

# %% [markdown]
# 6.	Use loc to display all columns for the sample with index 10.

# %%
df_iris.loc[:10]
# Out:
#      SL   SW   PL   PW Classification
# 0   5.1  3.5  1.4  0.2    Iris-setosa
# 1   4.9  3.0  1.4  0.2    Iris-setosa
# 2   4.7  3.2  1.3  0.2    Iris-setosa
# 3   4.6  3.1  1.5  0.2    Iris-setosa
# 4   5.0  3.6  1.4  0.2    Iris-setosa
# 5   5.4  3.9  1.7  0.4    Iris-setosa
# 6   4.6  3.4  1.4  0.3    Iris-setosa
# 7   5.0  3.4  1.5  0.2    Iris-setosa
# 8   4.4  2.9  1.4  0.2    Iris-setosa
# 9   4.9  3.1  1.5  0.1    Iris-setosa
# 10  5.4  3.7  1.5  0.2    Iris-setosa

# %% [markdown]
# 7.	Use iloc to display the values of the last row in the dataset.

# %%
df_iris.iloc[-1]
# Out:
# SL                           5.9
# SW                           3.0
# PL                           5.1
# PW                           1.8
# Classification    Iris-virginica
# Name: 149, dtype: object

# %% [markdown]
# 8.	Use loc to display the petal length and petal width for samples with indices 25 to 30 (inclusive).

# %%
df_iris.loc[25:30,["PL"]]
# Out:
#      PL
# 25  1.6
# 26  1.6
# 27  1.5
# 28  1.4
# 29  1.6
# 30  1.6

# %%
df_iris.loc[25:30,["PW"]]
# Out:
#      PW
# 25  0.2
# 26  0.4
# 27  0.2
# 28  0.2
# 29  0.2
# 30  0.2

# %% [markdown]
# 9.	Use iloc to display the sepal length and sepal width for the first 10 samples.

# %%
df_iris.iloc[:10,[0,1]]
# Out:
#     SL   SW
# 0  5.1  3.5
# 1  4.9  3.0
# 2  4.7  3.2
# 3  4.6  3.1
# 4  5.0  3.6
# 5  5.4  3.9
# 6  4.6  3.4
# 7  5.0  3.4
# 8  4.4  2.9
# 9  4.9  3.1

# %% [markdown]
# 10.	Use loc to display all columns for samples with target class 1.

# %%
df_iris.loc[1,:]
# Out:
# SL                        4.9
# SW                        3.0
# PL                        1.4
# PW                        0.2
# Classification    Iris-setosa
# Name: 1, dtype: object
